# %% [markdown]
# clone thư viện CUT

# %%
# !git clone https://github.com/taesungp/contrastive-unpaired-translation CUT
# Out:
# Cloning into 'CUT'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 238 (delta 0), reused 1 (delta 0), pack-reused 235
# Receiving objects: 100% (238/238), 17.90 MiB | 43.22 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
cd CUT
# Out:
# /content/CUT

# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 14.7MB/s
# ...
#      |████████████████████████████████| 204kB 54.2MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=23af0591a157c2a667e3e537aaa550d1e120e17bb7d3eb92b4754990827e87b0
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7412 sha256=4a036c4e4ad8ce0f0476f5c4a0c5818fcfd0617bac815d535b9241ece7dce9ae
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5712 sha256=3f6848d4719b7a164300e6f64e0a33cfa04f6796f1f9e867da03b9a6cc1645fe
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom GPUtil torchfile
# ...

# %% [markdown]
# Load Model

# %%
# !python test.py --dataroot /content/drive/MyDrive/test_gan --name dongho_CUT --CUT_mode CUT --phase test --epoch 17 --checkpoints_dir /content/drive/MyDrive/cut
# Out:
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#           checkpoints_dir: /content/drive/MyDrive/cut    	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/test_gan	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: 17                            	[default: latest]
#                      eval: False
#         flip_equivariance: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: xavier
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                lambda_GAN: 1.0
#                lambda_NCE: 1.0
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cut
# ...

# %% [markdown]
# Showing results

# %%
import os
res_path = '/content/CUT/results/dongho_CUT/test_17/images/'
fake = os.path.join(res_path,'fake_B')
real = os.path.join(res_path,'real_A')
style=os.path.join(res_path,'real_B')

# %%
import matplotlib.pyplot as plt
import numpy as np

i = np.random.randint(40)+1
fake_img = plt.imread(os.path.join(fake,'%02d.png'%i))
real_img = plt.imread(os.path.join(real,'%02d.png'%i))
style_img = plt.imread(os.path.join(style,'%02d.png'%i))
#plt.figure()
fig, ax = plt.subplots(1,3,figsize=(100,100))
ax[2].imshow(style_img)
ax[1].imshow(fake_img)
ax[0].imshow(real_img)
plt.show()
